# %%
#import SparkSession
from pyspark.sql import SparkSession
# Out:
# VBox()
# Starting Spark application
# <table>
# <tr><th>ID</th><th>YARN Application ID</th><th>Kind</th><th>State</th><th>Spark UI</th><th>Driver log</th><th>Current session?</th></tr><tr><td>1</td><td>application_1573127158758_0004</td><td>pyspark</td><td>idle</td><td><a target="_blank" href="http://ip-172-31-14-141.ec2.internal:20888/proxy/application_1573127158758_0004/">Link</a></td><td><a target="_blank" href="http://ip-172-31-8-151.ec2.internal:8042/node/containerlogs/container_1573127158758_0004_01_000001/livy">Link</a></td><td>✔</td></tr></table>
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# SparkSession available as 'spark'.
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
#create spar session object
spark=SparkSession.builder.appName('data_processing').getOrCreate()
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
# Load csv Dataset 
df=spark.read.csv('hdfs:///user/jquiro12/datasets/spark/sample_data.csv',inferSchema=True,header=True)
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
df.columns
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# ['ratings', 'age', 'experience', 'family', 'mobile']

# %%
columns_number = len(columns_number)
columns_number
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# 5

# %%
#Number of records on dataframe
rows_number = df.count()
rows_number
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# 33

# %%
#Sahpe

print((rows_number,columns_number))
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# (33, 5)

# %%
df.printSchema()
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# root
#  |-- ratings: integer (nullable = true)
#  |-- age: integer (nullable = true)
#  |-- experience: double (nullable = true)
#  |-- family: integer (nullable = true)
#  |-- mobile: string (nullable = true)

# %%
df.show(5)
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +-------+---+----------+------+-------+
# |ratings|age|experience|family| mobile|
# +-------+---+----------+------+-------+
# |      3| 32|       9.0|     3|   Vivo|
# |      3| 27|      13.0|     3|  Apple|
# |      4| 22|       2.5|     0|Samsung|
# |      4| 37|      16.5|     4|  Apple|
# |      5| 27|       9.0|     1|     MI|
# +-------+---+----------+------+-------+
# only showing top 5 rows

# %%
df.select('age','mobile').show(5)
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +---+-------+
# |age| mobile|
# +---+-------+
# | 32|   Vivo|
# | 27|  Apple|
# | 22|Samsung|
# | 37|  Apple|
# | 27|     MI|
# +---+-------+
# only showing top 5 rows

# %%
df.describe().show()
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +-------+------------------+------------------+------------------+------------------+------+
# |summary|           ratings|               age|        experience|            family|mobile|
# +-------+------------------+------------------+------------------+------------------+------+
# |  count|                33|                33|                33|                33|    33|
# |   mean|3.5757575757575757|30.484848484848484|10.303030303030303|1.8181818181818181|  null|
# | stddev|1.1188806636071336|  6.18527087180309| 6.770731351213326|1.8448330794164254|  null|
# |    min|                 1|                22|               2.5|                 0| Apple|
# |    max|                 5|                42|              23.0|                 5|  Vivo|
# +-------+------------------+------------------+------------------+------------------+------+

# %%
from pyspark.sql.types import StringType,DoubleType,IntegerType
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
#With column
df.withColumn("age_after_10_yrs",(df["age"] + 10)).show(10, False)
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +-------+---+----------+------+-------+----------------+
# |ratings|age|experience|family|mobile |age_after_10_yrs|
# +-------+---+----------+------+-------+----------------+
# |3      |32 |9.0       |3     |Vivo   |42              |
# |3      |27 |13.0      |3     |Apple  |37              |
# |4      |22 |2.5       |0     |Samsung|32              |
# |4      |37 |16.5      |4     |Apple  |47              |
# |5      |27 |9.0       |1     |MI     |37              |
# |4      |27 |9.0       |0     |Oppo   |37              |
# |5      |37 |23.0      |5     |Vivo   |47              |
# |5      |37 |23.0      |5     |Samsung|47              |
# |3      |22 |2.5       |0     |Apple  |32              |
# |3      |27 |6.0       |0     |MI     |37              |
# +-------+---+----------+------+-------+----------------+
# only showing top 10 rows

# %%
df.withColumn("age_double", df['age'].cast(DoubleType())).show(10, False)
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +-------+---+----------+------+-------+----------+
# |ratings|age|experience|family|mobile |age_double|
# +-------+---+----------+------+-------+----------+
# |3      |32 |9.0       |3     |Vivo   |32.0      |
# |3      |27 |13.0      |3     |Apple  |27.0      |
# |4      |22 |2.5       |0     |Samsung|22.0      |
# |4      |37 |16.5      |4     |Apple  |37.0      |
# |5      |27 |9.0       |1     |MI     |27.0      |
# |4      |27 |9.0       |0     |Oppo   |27.0      |
# |5      |37 |23.0      |5     |Vivo   |37.0      |
# |5      |37 |23.0      |5     |Samsung|37.0      |
# |3      |22 |2.5       |0     |Apple  |22.0      |
# |3      |27 |6.0       |0     |MI     |27.0      |
# +-------+---+----------+------+-------+----------+
# only showing top 10 rows

# %%
#Filter the records
df.filter(df['mobile'] == 'Vivo').select('age','ratings','mobile').show()
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +---+-------+------+
# |age|ratings|mobile|
# +---+-------+------+
# | 32|      3|  Vivo|
# | 37|      5|  Vivo|
# | 37|      4|  Vivo|
# | 37|      5|  Vivo|
# | 37|      4|  Vivo|
# +---+-------+------+

# %%
df.filter((df['mobile'] == 'Vivo') & (df['experience'] > 10)).show()
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +-------+---+----------+------+------+
# |ratings|age|experience|family|mobile|
# +-------+---+----------+------+------+
# |      5| 37|      23.0|     5|  Vivo|
# |      5| 37|      13.0|     1|  Vivo|
# +-------+---+----------+------+------+

# %%
df.select('mobile').distinct().show()
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +-------+
# | mobile|
# +-------+
# |     MI|
# |   Oppo|
# |Samsung|
# |   Vivo|
# |  Apple|
# +-------+

# %%
df.select('mobile').distinct().count()
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# 5

# %%
df.groupBy('mobile').count().show(5,False)
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +-------+-----+
# |mobile |count|
# +-------+-----+
# |MI     |8    |
# |Oppo   |7    |
# |Samsung|6    |
# |Vivo   |5    |
# |Apple  |7    |
# +-------+-----+

# %%
df.groupBy('mobile').count().orderBy('count',ascending=False).show(5,False)
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +-------+-----+
# |mobile |count|
# +-------+-----+
# |MI     |8    |
# |Oppo   |7    |
# |Apple  |7    |
# |Samsung|6    |
# |Vivo   |5    |
# +-------+-----+

# %%
# Value counts
df.groupBy('mobile').mean().show(5,False)
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +-------+------------------+------------------+------------------+------------------+
# |mobile |avg(ratings)      |avg(age)          |avg(experience)   |avg(family)       |
# +-------+------------------+------------------+------------------+------------------+
# |MI     |3.5               |30.125            |10.1875           |1.375             |
# |Oppo   |2.857142857142857 |28.428571428571427|10.357142857142858|1.4285714285714286|
# |Samsung|4.166666666666667 |28.666666666666668|8.666666666666666 |1.8333333333333333|
# |Vivo   |4.2               |36.0              |11.4              |1.8               |
# |Apple  |3.4285714285714284|30.571428571428573|11.0              |2.7142857142857144|
# +-------+------------------+------------------+------------------+------------------+

# %%
df.groupBy('mobile').sum().show()
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +-------+------------+--------+---------------+-----------+
# | mobile|sum(ratings)|sum(age)|sum(experience)|sum(family)|
# +-------+------------+--------+---------------+-----------+
# |     MI|          28|     241|           81.5|         11|
# |   Oppo|          20|     199|           72.5|         10|
# |Samsung|          25|     172|           52.0|         11|
# |   Vivo|          21|     180|           57.0|          9|
# |  Apple|          24|     214|           77.0|         19|
# +-------+------------+--------+---------------+-----------+

# %%
df.groupBy('mobile').max().show(5)
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +-------+------------+--------+---------------+-----------+
# | mobile|max(ratings)|max(age)|max(experience)|max(family)|
# +-------+------------+--------+---------------+-----------+
# |     MI|           5|      42|           23.0|          5|
# |   Oppo|           4|      42|           23.0|          2|
# |Samsung|           5|      37|           23.0|          5|
# |   Vivo|           5|      37|           23.0|          5|
# |  Apple|           4|      37|           16.5|          5|
# +-------+------------+--------+---------------+-----------+

# %%
df.groupBy('mobile').min().show(5)
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +-------+------------+--------+---------------+-----------+
# | mobile|min(ratings)|min(age)|min(experience)|min(family)|
# +-------+------------+--------+---------------+-----------+
# |     MI|           1|      27|            2.5|          0|
# |   Oppo|           2|      22|            6.0|          0|
# |Samsung|           2|      22|            2.5|          0|
# |   Vivo|           3|      32|            6.0|          0|
# |  Apple|           3|      22|            2.5|          0|
# +-------+------------+--------+---------------+-----------+

# %%
df.groupBy('mobile').agg({'experience':'sum'}).show(5,False)
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +-------+---------------+
# |mobile |sum(experience)|
# +-------+---------------+
# |MI     |81.5           |
# |Oppo   |72.5           |
# |Samsung|52.0           |
# |Vivo   |57.0           |
# |Apple  |77.0           |
# +-------+---------------+

# %%
from pyspark.sql.functions import udf
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
def price_range(brand):
    if brand in ['Samsung','Apple']:
        return 'High Price'
    elif brand =='MI':
        return 'Mid Price'
    else:
        return 'Low Price'
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
brand_udf = udf(price_range, StringType())

df.withColumn('price_range', brand_udf(df['mobile'])).show(10,False)
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +-------+---+----------+------+-------+-----------+
# |ratings|age|experience|family|mobile |price_range|
# +-------+---+----------+------+-------+-----------+
# |3      |32 |9.0       |3     |Vivo   |Low Price  |
# |3      |27 |13.0      |3     |Apple  |High Price |
# |4      |22 |2.5       |0     |Samsung|High Price |
# |4      |37 |16.5      |4     |Apple  |High Price |
# |5      |27 |9.0       |1     |MI     |Mid Price  |
# |4      |27 |9.0       |0     |Oppo   |Low Price  |
# |5      |37 |23.0      |5     |Vivo   |Low Price  |
# |5      |37 |23.0      |5     |Samsung|High Price |
# |3      |22 |2.5       |0     |Apple  |High Price |
# |3      |27 |6.0       |0     |MI     |Mid Price  |
# +-------+---+----------+------+-------+-----------+
# only showing top 10 rows

# %%
age_udf = udf(lambda age: "young" if age <= 30 else "senior", StringType())

df.withColumn("age_group",age_udf(df.age)).show(10,False)
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +-------+---+----------+------+-------+---------+
# |ratings|age|experience|family|mobile |age_group|
# +-------+---+----------+------+-------+---------+
# |3      |32 |9.0       |3     |Vivo   |senior   |
# |3      |27 |13.0      |3     |Apple  |young    |
# |4      |22 |2.5       |0     |Samsung|young    |
# |4      |37 |16.5      |4     |Apple  |senior   |
# |5      |27 |9.0       |1     |MI     |young    |
# |4      |27 |9.0       |0     |Oppo   |young    |
# |5      |37 |23.0      |5     |Vivo   |senior   |
# |5      |37 |23.0      |5     |Samsung|senior   |
# |3      |22 |2.5       |0     |Apple  |young    |
# |3      |27 |6.0       |0     |MI     |young    |
# +-------+---+----------+------+-------+---------+
# only showing top 10 rows

# %%
from pyspark.sql.functions import pandas_udf, PandasUDFType
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
def remaining_yrs(age):
    yrs_left=100-age

    return yrs_left
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
length_udf = udf(remaining_yrs, IntegerType())
df.withColumn("yrs_left", length_udf(df['age'])).show(10,False)
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +-------+---+----------+------+-------+--------+
# |ratings|age|experience|family|mobile |yrs_left|
# +-------+---+----------+------+-------+--------+
# |3      |32 |9.0       |3     |Vivo   |68      |
# |3      |27 |13.0      |3     |Apple  |73      |
# |4      |22 |2.5       |0     |Samsung|78      |
# |4      |37 |16.5      |4     |Apple  |63      |
# |5      |27 |9.0       |1     |MI     |73      |
# |4      |27 |9.0       |0     |Oppo   |73      |
# |5      |37 |23.0      |5     |Vivo   |63      |
# |5      |37 |23.0      |5     |Samsung|63      |
# |3      |22 |2.5       |0     |Apple  |78      |
# |3      |27 |6.0       |0     |MI     |73      |
# +-------+---+----------+------+-------+--------+
# only showing top 10 rows

# %%
def prod(rating,exp):
    x=rating*exp
    return x
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
prod_udf = udf(prod, DoubleType())

df.withColumn("product", prod_udf(df['ratings'],df['experience'])).show(10,False)
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +-------+---+----------+------+-------+-------+
# |ratings|age|experience|family|mobile |product|
# +-------+---+----------+------+-------+-------+
# |3      |32 |9.0       |3     |Vivo   |27.0   |
# |3      |27 |13.0      |3     |Apple  |39.0   |
# |4      |22 |2.5       |0     |Samsung|10.0   |
# |4      |37 |16.5      |4     |Apple  |66.0   |
# |5      |27 |9.0       |1     |MI     |45.0   |
# |4      |27 |9.0       |0     |Oppo   |36.0   |
# |5      |37 |23.0      |5     |Vivo   |115.0  |
# |5      |37 |23.0      |5     |Samsung|115.0  |
# |3      |22 |2.5       |0     |Apple  |7.5    |
# |3      |27 |6.0       |0     |MI     |18.0   |
# +-------+---+----------+------+-------+-------+
# only showing top 10 rows

# %%
#duplicate values
df.count()
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# 33

# %%
#drop duplicate values
df=df.dropDuplicates()
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
#validate new count
df.count()
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# 26

# %%
#drop column of dataframe
df_new=df.drop('mobile')
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
df_new.show(10)
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +-------+---+----------+------+
# |ratings|age|experience|family|
# +-------+---+----------+------+
# |      3| 32|       9.0|     3|
# |      4| 22|       2.5|     0|
# |      5| 27|       6.0|     0|
# |      4| 22|       6.0|     1|
# |      3| 27|       6.0|     0|
# |      2| 32|      16.5|     2|
# |      4| 27|       9.0|     0|
# |      2| 27|       9.0|     2|
# |      3| 37|      16.5|     5|
# |      4| 27|       6.0|     1|
# +-------+---+----------+------+
# only showing top 10 rows

# %%
# saving file (csv)
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
#target directory 
write_uri='s3://tetlab3/work/df_csv'
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
df.coalesce(1).write.format("csv").option("header","true").save(write_uri)
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
# parquet
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
#target location
parquet_uri='s3://tetlab3/work/df_parquet'
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
#save the data into parquet format 
df.write.format('parquet').save(parquet_uri)
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
